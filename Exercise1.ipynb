# %% [markdown]
# # Ex2 - Getting and Knowing your Data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset

# %%
pd.read_csv("C:/python_advance/pandas_data.csv")
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
df=pd.read_csv("C:/python_advance/pandas_data.csv")

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
df.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
#observation - matlab total no. of rows kitne present hai table ke under
df.shape
df.shape[0] #for rows like no of rows
df.shape[1] #for columns
# Out:
# 4622

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
df.shape[1]

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# ### Step 8. How is the dataset indexed?

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# ### Step 9. Which was the most-ordered item?

# %%
#if we take group by 
#groupby implement hota hai non aggregated column pe or support aggregate column
#1 technique
a = df.groupby("item_name").agg({"quantity":"sum"})
b = a.sort_values("quantity",ascending=False)
b
b.head(1)

#2technique(in slicing)
a = df.groupby("item_name").agg({"quantity":"sum"})
b = a.sort_values("quantity",ascending=False)[0:1]
b
# Out:
#               quantity
# item_name
# Chicken Bowl       761

# %% [markdown]
# ### Step 10. For the most-ordered item, how many items were ordered?

# %%
a = df.groupby("item_name").agg({"quantity":"sum"})
b = a.sort_values("quantity",ascending=False)[0:1]
b
b.quantity

# or we can write this like
b["quantity"]
# Out:
# item_name
# Chicken Bowl    761
# Name: quantity, dtype: int64

# %% [markdown]
# ### Step 11. What was the most ordered item in the choice_description column?

# %%
a = df.groupby("choice_description").agg({"quantity":"sum"})
b = a.sort_values("quantity",ascending=False)[0:1]
b
# Out:
#                     quantity
# choice_description
# [Diet Coke]              159

# %% [markdown]
# ### Step 12. How many items were orderd in total?

# %%
e = df["quantity"].sum()
print(e)

# or 

a= df.order_id.count()
print(a)
# for multiple(ek column ke liye ek bracet or 1 se jada ke liye 2)
# df[["quantity","item_name"]].sum()
# Out:
# 4972
# 4622

# %% [markdown]
# ### Step 13. Turn the item price into a float

# %%
df.item_price.dtype
# Out:
# dtype('O')

# %%
# astype () -its is a fucntion use to convert datatype

df.item_price.str.slice(1).astype("float")
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
# to remove from daatabase
df["item_price"] = df.item_price.str.slice(1).astype("float")

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %% [markdown]
# #### Step 13.a. Check the item price type

# %%
df.item_price.dtype
# Out:
# dtype('float64')

# %% [markdown]
# #### Step 13.b. Check the item price type

# %%
df.quantity.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ### Step 14. How much was the revenue for the period in the dataset?

# %%
revenue = df["quantity"] *df[ "item_price"]
e=revenue.sum()
print(e)
# Out:
# 39237.02

# %% [markdown]
# ### Step 15. How many orders were made in the period?

# %%
# f = df.order_id.count()
# print(f)(galat hai ye )

# or

g= df["order_id"].nunique() # nunique count de raha hai unique value ka
print(g)
# Out:
# 1834
# [   1    2    3 ... 1832 1833 1834]

# %% [markdown]
# ### Step 16. What is the average revenue amount per order?

# %%
df['revenue'] = df['quantity'] * df['item_price']
order_revenue = df.groupby('order_id')['revenue'].sum()
average_revenue_per_order = np.mean(order_revenue)

print("Average Revenue per Order:", average_revenue_per_order)

# %% [markdown]
# ### Step 17. How many different items are sold?
