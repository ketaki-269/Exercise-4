# %% [markdown]
# # US - Baby Names

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset

# %%
pd.read_csv("C:/python_advance/US_Baby_Names.csv")
# Out:
#          Unnamed: 0       Id     Name  Year Gender State  Count
# 0             11349    11350     Emma  2004      F    AK     62
# 1             11350    11351  Madison  2004      F    AK     48
# 2             11351    11352   Hannah  2004      F    AK     46
# 3             11352    11353    Grace  2004      F    AK     44
# 4             11353    11354    Emily  2004      F    AK     41
# ...             ...      ...      ...   ...    ...   ...    ...
# 1016390     5647421  5647422     Seth  2014      M    WY      5
# 1016391     5647422  5647423  Spencer  2014      M    WY      5
# 1016392     5647423  5647424     Tyce  2014      M    WY      5
# 1016393     5647424  5647425   Victor  2014      M    WY      5
# 1016394     5647425  5647426   Waylon  2014      M    WY      5
#
# [1016395 rows x 7 columns]

# %% [markdown]
# ### Step 3. Assign it to a variable called baby_names.

# %%
baby_names = pd.read_csv("C:/python_advance/US_Baby_Names.csv")

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
baby_names.head(10)
# Out:
#    Unnamed: 0     Id      Name  Year Gender State  Count
# 0       11349  11350      Emma  2004      F    AK     62
# 1       11350  11351   Madison  2004      F    AK     48
# 2       11351  11352    Hannah  2004      F    AK     46
# 3       11352  11353     Grace  2004      F    AK     44
# 4       11353  11354     Emily  2004      F    AK     41
# 5       11354  11355   Abigail  2004      F    AK     37
# 6       11355  11356    Olivia  2004      F    AK     33
# 7       11356  11357  Isabella  2004      F    AK     30
# 8       11357  11358    Alyssa  2004      F    AK     29
# 9       11358  11359    Sophia  2004      F    AK     28

# %% [markdown]
# ### Step 5. Delete the column 'Unnamed: 0' and 'Id'

# %%
baby_names.drop(['Unnamed: 0', 'Id'], axis=1, inplace=True)
# 9165800969

# %%
baby_names
# Out:
#             Name  Year Gender State  Count
# 0           Emma  2004      F    AK     62
# 1        Madison  2004      F    AK     48
# 2         Hannah  2004      F    AK     46
# 3          Grace  2004      F    AK     44
# 4          Emily  2004      F    AK     41
# ...          ...   ...    ...   ...    ...
# 1016390     Seth  2014      M    WY      5
# 1016391  Spencer  2014      M    WY      5
# 1016392     Tyce  2014      M    WY      5
# 1016393   Victor  2014      M    WY      5
# 1016394   Waylon  2014      M    WY      5
#
# [1016395 rows x 5 columns]

# %% [markdown]
# ### Step 6. Is there more male or female names in the dataset?

# %%
baby_names
# Out:
#             Name  Year Gender State  Count
# 0           Emma  2004      F    AK     62
# 1        Madison  2004      F    AK     48
# 2         Hannah  2004      F    AK     46
# 3          Grace  2004      F    AK     44
# 4          Emily  2004      F    AK     41
# ...          ...   ...    ...   ...    ...
# 1016390     Seth  2014      M    WY      5
# 1016391  Spencer  2014      M    WY      5
# 1016392     Tyce  2014      M    WY      5
# 1016393   Victor  2014      M    WY      5
# 1016394   Waylon  2014      M    WY      5
#
# [1016395 rows x 5 columns]

# %%
print(baby_names['Gender'].value_counts())
# Out:
# Gender
# F    558846
# M    457549
# Name: count, dtype: int64

# %% [markdown]
# ### Step 7. Group the dataset by name and assign to names

# %%
#is questions me similar name ka count nikalna hai 
# jo mene kiya tha galat kiya tha 
# names = baby_names.groupby["Name"].agg({"Name": "count"})
# names

#by sir 
names = baby_names.Name.value_counts()
names
# Out:
# Name
# Riley        1112
# Avery        1080
# Jordan       1073
# Peyton       1064
# Hayden       1049
#              ...
# Anaka           1
# Montanna        1
# Thaddaeus       1
# Miroslav        1
# Ackley          1
# Name: count, Length: 17632, dtype: int64

# %% [markdown]
# ### Step 8. How many different names exist in the dataset?

# %%
baby_names['Name'].nunique()
# Out:
# 17632

# %% [markdown]
# ### Step 9. What is the name with most occurrences?

# %%
baby_names['Name'].max()
# Out:
# 'Zyriah'

# %% [markdown]
# ### Step 10. How many different names have the least occurrences?

# %%
a= baby_names['Name'].value_counts()
a
b= a.min()
b
# Out:
# np.int64(1)

# %%
baby_names
# Out:
#             Name  Year Gender State  Count
# 0           Emma  2004      F    AK     62
# 1        Madison  2004      F    AK     48
# 2         Hannah  2004      F    AK     46
# 3          Grace  2004      F    AK     44
# 4          Emily  2004      F    AK     41
# ...          ...   ...    ...   ...    ...
# 1016390     Seth  2014      M    WY      5
# 1016391  Spencer  2014      M    WY      5
# 1016392     Tyce  2014      M    WY      5
# 1016393   Victor  2014      M    WY      5
# 1016394   Waylon  2014      M    WY      5
#
# [1016395 rows x 5 columns]

# %%
baby_names.Name.value_counts()[-2:-1]
# Out:
# Name
# Miroslav    1
# Name: count, dtype: int64

# %%
names_counts = baby_names.groupby('Name')['Count'].sum()

# %%
names_counts
# Out:
# Name
# Aaban        12
# Aadan        23
# Aadarsh       5
# Aaden      3426
# Aadhav        6
#            ...
# Zyra         42
# Zyrah        11
# Zyren         6
# Zyria        59
# Zyriah       58
# Name: Count, Length: 17632, dtype: int64

# %% [markdown]
# ### Step 11. What is the median name occurrence?

# %%
names
# Out:
# Name
# Riley        1112
# Avery        1080
# Jordan       1073
# Peyton       1064
# Hayden       1049
#              ...
# Anaka           1
# Montanna        1
# Thaddaeus       1
# Miroslav        1
# Ackley          1
# Name: count, Length: 17632, dtype: int64

# %%
baby_names['Count'].median()
# Out:
# np.float64(11.0)

# %%
names_counts.median()
# Out:
# np.float64(49.0)

# %% [markdown]
# ### Step 12. What is the standard deviation of names?

# %%
names_counts.std()
# Out:
# np.float64(11006.06946789057)

# %%
# by sir
baby_names.Count.std()
# Out:
# np.float64(97.39734648617814)

# %% [markdown]
# ### Step 13. Get a summary with the mean, min, max, std and quartiles.

# %%
names_counts.describe()
# Out:
# count     17632.000000
# mean       2008.932169
# std       11006.069468
# min           5.000000
# 25%          11.000000
# 50%          49.000000
# 75%         337.000000
# max      242874.000000
# Name: Count, dtype: float64
